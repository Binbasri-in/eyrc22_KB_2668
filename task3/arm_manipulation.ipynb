# %% [markdown]
# ### Notes
#
# ##### Important Topics
#     /camera/color/image_raw2
#     /camera/depth/image_raw2
#     /cmd_vel
#     /ebot/camera1/camera_info
#     /ebot/camera1/image_raw
#     /tf
#     /tf_static
#
#
#
#     /ebot/laser/scan
#     /gripper_controller/state
#     /arm_controller/state
#     /joint_states
#     /odom

# %% [markdown]
# ROS commands
#
# rostopic list
#
# rostopic type [topic]
#
# rosmsg show geometry_msgs/Twist
#
# rostopic info /turtle1/cmd_vel
#
# rostopic pub [topic] [msg_type] [args]
#
# rostopic echo [topic]

# %% [markdown]
#     /arm_controller/command
#     /arm_controller/follow_joint_trajectory/cancel
#     /arm_controller/follow_joint_trajectory/feedback
#     /arm_controller/follow_joint_trajectory/goal
#     /arm_controller/follow_joint_trajectory/result
#     /arm_controller/follow_joint_trajectory/status
#     /arm_controller/state
#     /attached_collision_object
#     /camera/color/camera_info2
#     /camera/color/image_raw2
#     /camera/color/image_raw2/compressed
#     /camera/color/image_raw2/compressed/parameter_descriptions
#     /camera/color/image_raw2/compressed/parameter_updates
#     /camera/color/image_raw2/compressedDepth
#     /camera/color/image_raw2/compressedDepth/parameter_descriptions
#     /camera/color/image_raw2/compressedDepth/parameter_updates
#     /camera/color/image_raw2/theora
#     /camera/color/image_raw2/theora/parameter_descriptions
#     /camera/color/image_raw2/theora/parameter_updates
#     /camera/depth/camera_info2
#     /camera/depth/image_raw2
#     /camera2/depth/points2
#     /camera2/parameter_descriptions
#     /camera2/parameter_updates
#     /clock
#     /cmd_vel
#     /collision_object
#     /ebot/camera1/camera_info
#     /ebot/camera1/image_raw
#     /ebot/camera1/image_raw/compressed
#     /ebot/camera1/image_raw/compressed/parameter_descriptions
#     /ebot/camera1/image_raw/compressed/parameter_updates
#     /ebot/camera1/image_raw/compressedDepth
#     /ebot/camera1/image_raw/compressedDepth/parameter_descriptions
#     /ebot/camera1/image_raw/compressedDepth/parameter_updates
#     /ebot/camera1/image_raw/theora
#     /ebot/camera1/image_raw/theora/parameter_descriptions
#     /ebot/camera1/image_raw/theora/parameter_updates
#     /ebot/camera1/parameter_descriptions
#     /ebot/camera1/parameter_updates
#     /ebot/laser/scan
#     /execute_trajectory/cancel
#     /execute_trajectory/feedback
#     /execute_trajectory/goal
#     /execute_trajectory/result
#     /execute_trajectory/status
#     /gazebo/base_collision
#     /gazebo/link_states
#     /gazebo/model_states
#     /gazebo/parameter_descriptions
#     /gazebo/parameter_updates
#     /gazebo/performance_metrics
#     /gazebo/set_link_state
#     /gazebo/set_model_state
#     /gripper_controller/command
#     /gripper_controller/follow_joint_trajectory/cancel
#     /gripper_controller/follow_joint_trajectory/feedback
#     /gripper_controller/follow_joint_trajectory/goal
#     /gripper_controller/follow_joint_trajectory/result
#     /gripper_controller/follow_joint_trajectory/status
#     /gripper_controller/state
#     /imu
#     /joint_states
#     /move_group/cancel
#     /move_group/display_contacts
#     /move_group/display_planned_path
#     /move_group/feedback
#     /move_group/goal
#     /move_group/monitored_planning_scene
#     /move_group/plan_execution/parameter_descriptions
#     /move_group/plan_execution/parameter_updates
#     /move_group/planning_pipelines/ompl/ompl/parameter_descriptions
#     /move_group/planning_pipelines/ompl/ompl/parameter_updates
#     /move_group/planning_scene_monitor/parameter_descriptions
#     /move_group/planning_scene_monitor/parameter_updates
#     /move_group/result
#     /move_group/sense_for_plan/parameter_descriptions
#     /move_group/sense_for_plan/parameter_updates
#     /move_group/status
#     /move_group/trajectory_execution/parameter_descriptions
#     /move_group/trajectory_execution/parameter_updates
#     /odom
#     /pickup/cancel
#     /pickup/feedback
#     /pickup/goal
#     /pickup/result
#     /pickup/status
#     /place/cancel
#     /place/feedback
#     /place/goal
#     /place/result
#     /place/status
#     /planning_scene
#     /planning_scene_world
#     /recognized_object_array
#     /rosout
#     /rosout_agg
#     /rviz_moveit_motion_planning_display/robot_interaction_interactive_marker_topic/feedback
#     /rviz_moveit_motion_planning_display/robot_interaction_interactive_marker_topic/update
#     /rviz_moveit_motion_planning_display/robot_interaction_interactive_marker_topic/update_full
#     /rviz_ubuntu_14205_9209585148531826654/motionplanning_planning_scene_monitor/parameter_descriptions
#     /rviz_ubuntu_14205_9209585148531826654/motionplanning_planning_scene_monitor/parameter_updates
#     /sequence_move_group/cancel
#     /sequence_move_group/feedback
#     /sequence_move_group/goal
#     /sequence_move_group/result
#     /sequence_move_group/status
#     /sysInfo
#     /tf
#     /tf_static
#     /trajectory_execution_event

# %% [markdown]
#     Result from pose1
#
#     ARM
#
#     [ INFO] [1669640708.573606822, 9.262000000]: Ready to take commands for planning group arm.
#     [INFO] [1669640708.576199, 0.000000]: Planning Group: ebot_base
#     [INFO] [1669640708.578927, 9.262000]: End Effector Link: wrist_3_link
#     [INFO] [1669640708.581804, 9.262000]: Group Names: ['arm', 'gripper']
#     [INFO] [1669640708.586687, 9.263000]:  >>> Ur5Moveit init done.
#     [INFO] [1669640708.807387, 9.328000]:
#     End-Effector (wrist_3_link) Pose:
#
#     x: 0.24987913980791684
#     y: 0.10903285478986095
#     z: 0.8257750670979457
#
#     roll: 3.1326778942951954
#     pitch: 3.8173039840366576e-05
#     yaw: 1.570002054173128
#
#     [INFO] [1669640708.811058, 9.328000]:
#     Joint Values:
#
#     ur5_shoulder_pan_joint: -0.07473639189613633
#     ur5_shoulder_lift_joint: -0.5402273282706708
#     ur5_elbow_joint: 0.01600993290810516
#     ur5_wrist_1_joint: 0.013439246235220083
#     ur5_wrist_2_joint: -0.02924625917303892
#     ur5_wrist_3_joint: -0.0019265106964057278
#
#     gripper
#
#     [ INFO] [1669640020.673948865, 27.079000000]: Ready to take commands for planning group gripper.
#     [INFO] [1669640020.676851, 27.079000]: Planning Group: ebot_base
#     [INFO] [1669640020.679436, 27.080000]: End Effector Link: gripper_finger1_knuckle_link
#     [INFO] [1669640020.681871, 27.081000]: Group Names: ['arm', 'gripper']
#     [INFO] [1669640020.693727, 27.082000]:  >>> Ur5Moveit init done.
#     [INFO] [1669640020.897864, 27.083000]:
#     End-Effector (gripper_finger1_knuckle_link) Pose:
#
#     x: 0.383731868745402
#     y: 0.07860080711179335
#     z: 0.8279825328770325
#
#     roll: -7.48271738221433e-05
#     pitch: -0.014434747117522444
#     yaw: 0.008797450024300163
